# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

pd.set_option('display.max_columns', None)

# %%
df = pd.read_pickle('data/2021_stats_final.pkl')
df.columns = [column.capitalize() for column in df.columns]
df
# Out:
#      Jornada      Fecha                Local            Visitante  \
# 0          1 2021-07-17  Deportivo Municipal        Univ. Técnica
# 1          1 2021-07-18     Univ. San Martín   Carlos A. Mannucci
# 2          1 2021-07-18    Academia Cantolao     Sporting Cristal
# 3          1 2021-07-18       Sport Huancayo           FBC Melgar
# 4          1 2021-07-19    Sport Boys Callao            Cienciano
# ..       ...        ...                  ...                  ...
# 148       17 2021-10-30     Alianza Atlético  Deportivo Municipal
# 149       17 2021-10-30             Cusco FC       Sport Huancayo
# 150       17 2021-10-30        Univ. Técnica     Univ. San Martín
# 151       17 2021-10-30   Carlos A. Mannucci    Academia Cantolao
# 152       17 2021-10-31           FBC Melgar        Universitario
#
#      Goles local  Goles visitante  \
# 0              1                1
# 1              0                2
# 2              2                4
# ...

# %%
df.dropna()
# Out:
#      Jornada      Fecha                Local            Visitante  \
# 0          1 2021-07-17  Deportivo Municipal        Univ. Técnica
# 1          1 2021-07-18     Univ. San Martín   Carlos A. Mannucci
# 2          1 2021-07-18    Academia Cantolao     Sporting Cristal
# 3          1 2021-07-18       Sport Huancayo           FBC Melgar
# 4          1 2021-07-19    Sport Boys Callao            Cienciano
# ..       ...        ...                  ...                  ...
# 144       17 2021-10-29            Cienciano         Alianza Lima
# 146       17 2021-10-30           Binacional  Univ. César Vallejo
# 147       17 2021-10-30      Alianza Huánuco          Ayacucho FC
# 150       17 2021-10-30        Univ. Técnica     Univ. San Martín
# 152       17 2021-10-31           FBC Melgar        Universitario
#
#      Goles local  Goles visitante  \
# 0              1                1
# 1              0                2
# 2              2                4
# ...
