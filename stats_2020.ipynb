# %%
# Importando Librerías
import re
import json
import pickle
import pprint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options

from classes.game import Game
import warnings
warnings.filterwarnings("ignore")

pd.set_option('display.max_columns', None)

# %%
df_2020 = pd.read_pickle('data/2020.pkl')
df_2020
# Out:
#      Jornada      Fecha                  Local            Visitante  \
# 0          1 2020-01-02             FBC Melgar        Universitario
# 1          1 2020-01-02           Alianza Lima      Alianza Huánuco
# 2          1 2020-01-02          Univ. Técnica     Sporting Cristal
# 3          1 2020-01-02         Sport Huancayo        Atlético Grau
# 4          1 2020-02-02    Univ. César Vallejo  Deportivo Municipal
# ..       ...        ...                    ...                  ...
# 185       19 2020-10-19            Ayacucho FC      FC Carlos Stein
# 186       19 2020-10-19  Deportivo Llacuabamba  Univ. César Vallejo
# 187       19 2020-10-19          Universitario             Cusco FC
# 188       19 2020-10-19          Atlético Grau        Univ. Técnica
# 189       19 2020-10-20     Carlos A. Mannucci       Sport Huancayo
#
#      Goles Local  Goles Visitante  \
# 0              1                2
# 1              2                3
# 2              2                1
# 3              1                0
# 4              1                1
# ..           ...              ...
# 185            3                0
# 186            2                3
# 187            3                2
# 188            0                0
# 189            0                1
#
#                                               Link
# 0    https://www.ceroacero.es/match.php?id=7324623
# 1    https://www.ceroacero.es/match.php?id=7324624
# 2    https://www.ceroacero.es/match.php?id=7324625
# 3    https://www.ceroacero.es/match.php?id=7324626
# 4    https://www.ceroacero.es/match.php?id=7324627
# ..                                             ...
# 185  https://www.ceroacero.es/match.php?id=7324816
# 186  https://www.ceroacero.es/match.php?id=7324815
# 187  https://www.ceroacero.es/match.php?id=7324820
# 188  https://www.ceroacero.es/match.php?id=7324818
# 189  https://www.ceroacero.es/match.php?id=7324817
#
# [190 rows x 7 columns]

# %%
matches_links = df_2020.Link.values

# %%
anio_2020 = Game()

# %%
stats_column = []
for link in matches_links:

    anio_2020.get_web(link)

    stats_column.append(anio_2020.game_stats())

# %%
df_2020['stats'] = pd.Series(stats_column)

# %%
df_2020
# Out:
#      Jornada      Fecha                  Local            Visitante  \
# 0          1 2020-01-02             FBC Melgar        Universitario
# 1          1 2020-01-02           Alianza Lima      Alianza Huánuco
# 2          1 2020-01-02          Univ. Técnica     Sporting Cristal
# 3          1 2020-01-02         Sport Huancayo        Atlético Grau
# 4          1 2020-02-02    Univ. César Vallejo  Deportivo Municipal
# ..       ...        ...                    ...                  ...
# 185       19 2020-10-19            Ayacucho FC      FC Carlos Stein
# 186       19 2020-10-19  Deportivo Llacuabamba  Univ. César Vallejo
# 187       19 2020-10-19          Universitario             Cusco FC
# 188       19 2020-10-19          Atlético Grau        Univ. Técnica
# 189       19 2020-10-20     Carlos A. Mannucci       Sport Huancayo
#
#      Goles Local  Goles Visitante  \
# 0              1                2
# 1              2                3
# 2              2                1
# 3              1                0
# 4              1                1
# ..           ...              ...
# 185            3                0
# 186            2                3
# 187            3                2
# 188            0                0
# 189            0                1
#
#                                               Link  \
# 0    https://www.ceroacero.es/match.php?id=7324623
# 1    https://www.ceroacero.es/match.php?id=7324624
# 2    https://www.ceroacero.es/match.php?id=7324625
# 3    https://www.ceroacero.es/match.php?id=7324626
# 4    https://www.ceroacero.es/match.php?id=7324627
# ..                                             ...
# 185  https://www.ceroacero.es/match.php?id=7324816
# 186  https://www.ceroacero.es/match.php?id=7324815
# 187  https://www.ceroacero.es/match.php?id=7324820
# 188  https://www.ceroacero.es/match.php?id=7324818
# 189  https://www.ceroacero.es/match.php?id=7324817
#
#                                                  stats
# 0    {'REMATES A PUERTA': ['7', '2'], 'TIROS': ['20...
# 1    {'REMATES A PUERTA': ['4', '5'], 'TIROS': ['15...
# 2    {'REMATES A PUERTA': ['5', '6'], 'TIROS': ['19...
# 3    {'REMATES A PUERTA': ['6', '3'], 'TIROS': ['24...
# 4    {'REMATES A PUERTA': ['6', '1'], 'TIROS': ['18...
# ..                                                 ...
# 185  {'REMATES A PUERTA': ['7', '3'], 'TIROS': ['16...
# 186  {'REMATES A PUERTA': ['4', '8'], 'TIROS': ['14...
# 187  {'REMATES A PUERTA': ['4', '8'], 'TIROS': ['10...
# 188  {'REMATES A PUERTA': ['3', '1'], 'TIROS': ['10...
# 189  {'REMATES A PUERTA': ['2', '4'], 'TIROS': ['12...
#
# [190 rows x 8 columns]

# %%
def clean_stats_column(dictionary):
    local_visit = {}
    for key, value in dictionary.items():
        local_visit[key+' LOCAL'] = value[0]
        local_visit[key+' VISITANTE'] = value[1]

    return local_visit

# %%
df_2020['stats'] = df_2020['stats'].apply(lambda x: clean_stats_column(x))

# %%
df_2020_clean = pd.concat([df_2020.drop(['stats'], axis=1), df_2020['stats'].apply(pd.Series)], axis=1)
df_2020_clean
# Out:
#      Jornada      Fecha                  Local            Visitante  \
# 0          1 2020-01-02             FBC Melgar        Universitario
# 1          1 2020-01-02           Alianza Lima      Alianza Huánuco
# 2          1 2020-01-02          Univ. Técnica     Sporting Cristal
# 3          1 2020-01-02         Sport Huancayo        Atlético Grau
# 4          1 2020-02-02    Univ. César Vallejo  Deportivo Municipal
# ..       ...        ...                    ...                  ...
# 185       19 2020-10-19            Ayacucho FC      FC Carlos Stein
# 186       19 2020-10-19  Deportivo Llacuabamba  Univ. César Vallejo
# 187       19 2020-10-19          Universitario             Cusco FC
# 188       19 2020-10-19          Atlético Grau        Univ. Técnica
# 189       19 2020-10-20     Carlos A. Mannucci       Sport Huancayo
#
#      Goles Local  Goles Visitante  \
# 0              1                2
# 1              2                3
# 2              2                1
# 3              1                0
# 4              1                1
# ..           ...              ...
# 185            3                0
# 186            2                3
# 187            3                2
# 188            0                0
# 189            0                1
#
#                                               Link REMATES A PUERTA LOCAL  \
# 0    https://www.ceroacero.es/match.php?id=7324623                      7
# 1    https://www.ceroacero.es/match.php?id=7324624                      4
# 2    https://www.ceroacero.es/match.php?id=7324625                      5
# 3    https://www.ceroacero.es/match.php?id=7324626                      6
# 4    https://www.ceroacero.es/match.php?id=7324627                      6
# ..                                             ...                    ...
# 185  https://www.ceroacero.es/match.php?id=7324816                      7
# 186  https://www.ceroacero.es/match.php?id=7324815                      4
# 187  https://www.ceroacero.es/match.php?id=7324820                      4
# 188  https://www.ceroacero.es/match.php?id=7324818                      3
# 189  https://www.ceroacero.es/match.php?id=7324817                      2
#
#     REMATES A PUERTA VISITANTE TIROS LOCAL TIROS VISITANTE  \
# 0                            2          20               7
# 1                            5          15               9
# 2                            6          19              14
# 3                            3          24               4
# 4                            1          18               5
# ..                         ...         ...             ...
# 185                          3          16               5
# 186                          8          14              13
# 187                          8          10              23
# 188                          1          10               7
# 189                          4          12               9
#
#     FUERAS DE JUEGO LOCAL FUERAS DE JUEGO VISITANTE FALTAS LOCAL  \
# 0                       1                         1           15
# 1                     NaN                       NaN           15
# 2                       4                         0           21
# 3                       3                         2            9
# 4                       1                         4           13
# ..                    ...                       ...          ...
# 185                     4                         0           14
# 186                     2                         4           13
# 187                     1                         1           15
# 188                   NaN                       NaN           10
# 189                     1                         0           16
#
#     FALTAS VISITANTE SAQUES DE ESQUINA LOCAL SAQUES DE ESQUINA VISITANTE  \
# 0                 21                       8                           3
# 1                  9                       7                           2
# 2                  8                       2                           5
# 3                  8                      13                           4
# 4                 18                      13                           1
# ..               ...                     ...                         ...
# 185               13                       4                           2
# 186               24                       5                           5
# 187               18                       5                           4
# 188               27                       9                           4
# 189               14                       4                           8
#
#     POSESIÓN LOCAL POSESIÓN VISITANTE
# 0             59 %               41 %
# 1             54 %               46 %
# 2             39 %               61 %
# 3             65 %               35 %
# 4             75 %               25 %
# ..             ...                ...
# 185           56 %               44 %
# 186           47 %               53 %
# 187           56 %               44 %
# 188           61 %               39 %
# 189           52 %               48 %
#
# [190 rows x 19 columns]

# %%
df_2020_clean.to_pickle('data/2020_stats_final.pkl')
